# %% [markdown]
# Q1: Understanding Central Tendency
#
# Data: [10, 12, 11, 15, 14, 13, 12]
#
# Mean = (10+12+11+15+14+13+12) ÷ 7 = 12.43
#
# Median = 12
#
# Mode = 12
# Most representative value: 12
#
# Q2: Mean in Real Life
#
# Marks: [12, 15, 14, 16, 18, 20, 19]
#
# Sum = 114
#
# Mean = 114 ÷ 7 = 16.29
#
#  Answer:
# The average score is 16.29.
#
# Q3: Mode in Real Life
#
# Shoe sizes: [7, 8, 9, 8, 8, 10, 7, 9]
#
# Mode = 8
#
#  Answer:
# Size 8 is sold the most.
#
# Q4: Median in Real Life
#
# Car prices: [$8,000, $9,500, $10,200, $11,000, $50,000]
#
# Median = $10,200
#
# Q5: Dispersion Introduction
#
# Times (minutes): [25, 30, 27, 35, 40]
#
# Range = 40 − 25 = 15 minutes
#
# Q6: Range in Action
#
# Apple weights (kg): [100, 105, 98, 110, 120]
#
# Range = 120 − 98 = 22 kg
#
# Q7: Variance for Decision-Making
#
# Company A variance = 6
#
# Company B variance = 15
#
#  Answer:
# Company A is more consistent.
#
# Q8: Standard Deviation in Context
#
# Coin A SD = $30
#
# Coin B SD = $120
#
# Riskier coin: Coin B
# Higher standard deviation means prices fluctuate more, so investment risk is higher.
#
# Q9: Combining Measures
#
# Electricity usage (kWh): [400, 420, 390, 450, 410]
#
# Mean:
#
# (400+420+390+450+410) ÷ 5 = 414 kWh
#
# Standard Deviation:
#
# SD ≈ 20.6 kWh
#
#
# Q10: Practical Application
#
# Basketball points: [15, 18, 20, 22, 25, 17, 19, 21]
#
# Mean:
#
# 157 ÷ 8 = 19.63
#
# Median:
#
# (19 + 20) ÷ 2 = 19.5
#
# Mode:
#
# No mode (all values unique)
#
# Range:
#
# 25 − 15 = 10
#
# Standard Deviation:
#
# SD ≈ 3.1
